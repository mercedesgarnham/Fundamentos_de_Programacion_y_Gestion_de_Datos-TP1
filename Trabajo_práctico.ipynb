# %% [markdown]
# <a href="https://colab.research.google.com/github/mercedesgarnham/Fundamentos_de_Programacion_y_Gestion_de_Datos-TP1/blob/main/Trabajo_pr%C3%A1ctico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Trabajo práctico
#
#
# *   Fecha de entrega: hasta el 22 de junio de 2026
# *   Modalidad de trabajo: grupal (1, 2 o 3 integrantes)
# *   Entregar un archivo de extensión .ipynb o compartir link de colab con permisos de editor.
# *   El archivo iris.csv se encuentra en la pestaña "Unidad 3"
#
#
#
# Integrantes:
#
# Apellido y Nombre: Didier Garnham Mercedes DNI: 35.242.541
#
# Apellido y Nombre: Glavina Juliana DNI: ..................
#
# Apellido y Nombre: Romer Guadalupe DNI: ..................

# %% [markdown]
# ## Análisis Exploratorio del Dataset Iris
#
# Este ejercicio te guiará a través de la carga, descripción y análisis del famoso dataset "Iris", haciendo énfasis en el uso de funciones personalizadas, ciclos (`for`, `while`) y condicionales (`if`/`elif`/`else`).
#
# **Tu tarea es desarrollar un programa Python que realice los siguientes 7 puntos:**
#
# 1.  **Lectura del Dataset**
#     *   Importa la librería `pandas`.
#     *   Carga el archivo `iris.csv` en un DataFrame de `pandas`. Asigna el DataFrame a la variable `df_iris`.
#
# 2.  **Descripción General del Dataset**
#     *   Muestra las primeras 5 filas (`.head()`).
#     *   Muestra la información general (`.info()`).
#     *   Muestra las estadísticas descriptivas (`.describe()`).
#     *   Verifica la cantidad de valores faltantes por columna (`.isnull().sum()`).
#
# 3.  **Análisis por Especie: Conteo y Promedio de Características**
#     *   Calcula y muestra la cantidad de registros para cada especie presente en el dataset. Sugerencia utilizar un contador.
#     *   Define una **función personalizada** llamada `calcular_promedio(lista_numeros)` que reciba una lista de números y devuelva su promedio. No utilices funciones de `numpy` o `pandas` dentro de esta función.
#     *   Para cada especie, usa tu función `calcular_promedio` para obtener el promedio de las características numéricas (`sepal_length`, `sepal_width`, `petal_length`, `petal_width`).
#
# 4.  **Almacenamiento de Promedios por Especie (1 punto):**
#     *   Guarda los promedios calculados para cada característica de cada especie en una estructura de datos adecuada (por ejemplo, una lista de tuplas o una lista de diccionarios, donde cada elemento represente una especie y sus promedios). Imprime esta estructura.
#
# 5.  **Comparación Interactiva de Características entre Especies:**
#     *   Define una **función** que pida al usuario qué característica numérica desea comparar (ej. 'sepal_length', 'petal_width').
#     *   Utiliza un ciclo y condicionales para recorrer los promedios almacenados en el punto 4.
#     *   La función debe identificar y mostrar cuál especie tiene el valor más alto para la característica seleccionada por el usuario.
#
# 6.  **Búsqueda y Conteo de un Dato Específico:**
#     *   Pide al usuario que ingrese un valor (numérico o de texto) y una columna del dataset (`df_iris`) donde buscar ese valor.
#     *   Utiliza un ciclo (`for` o `while`) para recorrer la columna especificada.
#     *   Cuenta y muestra cuántas veces se repite el dato ingresado por el usuario en esa columna.
#
# 7.  **Cálculo de Suma Total:**
#     *   Pide al usuario que ingrese el nombre de una columna numérica (`sepal_length`, `sepal_width`, `petal_length`, `petal_width`).
#     *   Calcula la suma total de todos los valores en esa columna utilizando un ciclo (`for` o `while`) y muestra el resultado.

# %%
#1. Lectura del Dataset

import pandas as pd

url = "https://raw.githubusercontent.com/mercedesgarnham/Fundamentos_de_Programacion_y_Gestion_de_Datos-TP1/main/IRIS.csv"
df_iris = pd.read_csv(url)

# %%
#2. Descripción General del Dataset
print(df_iris.head(),"\n")
print(df_iris.info(),"\n")
print(df_iris.describe(),"\n")
print(df_iris.isnull().sum(),"\n")
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None
#
#        sepal_length  sepal_width  petal_length  petal_width
# ...

# %%
#3. Análisis por Especie: Conteo y Promedio de Características
print(df_iris['species'].value_counts())
print("\n")

def calcular_promedio(lista_numeros):
    suma = 0
    for numero in lista_numeros:
        suma += numero
    if len(lista_numeros) == 0:
      promedio = 0
    else:
      promedio = suma / len(lista_numeros)
    return promedio

for especie in df_iris['species'].unique():
  print("Datos de la especie",especie)
  datos_especie = df_iris[df_iris['species'] == especie]
  columnas_numericas = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
  for columna in columnas_numericas:
    promedio = calcular_promedio(datos_especie[columna])
    print(columna," = ",promedio)
  print("\n")
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64
#
#
# Datos de la especie Iris-setosa
# sepal_length  =  5.005999999999999
# sepal_width  =  3.4180000000000006
# petal_length  =  1.464
# petal_width  =  0.2439999999999999
#
#
# Datos de la especie Iris-versicolor
# sepal_length  =  5.936
# sepal_width  =  2.7700000000000005
# petal_length  =  4.26
# petal_width  =  1.3259999999999998
#
#
# Datos de la especie Iris-virginica
# sepal_length  =  6.587999999999998
# sepal_width  =  2.9739999999999998
# petal_length  =  5.552
# petal_width  =  2.026

# %%
#4. Almacenamiento de Promedios por Especie
promedios_especies = []
columnas_numericas = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']

for especie in df_iris['species'].unique():
  datos_especie = df_iris[df_iris['species'] == especie]
  promedios_especie = {'especie': especie}

  for columna in columnas_numericas:
    promedio = calcular_promedio(datos_especie[columna])
    promedios_especie[columna] = promedio

  promedios_especies.append(promedios_especie)

print(promedios_especies)
# Out:
# [{'especie': 'Iris-setosa', 'sepal_length': 5.005999999999999, 'sepal_width': 3.4180000000000006, 'petal_length': 1.464, 'petal_width': 0.2439999999999999}, {'especie': 'Iris-versicolor', 'sepal_length': 5.936, 'sepal_width': 2.7700000000000005, 'petal_length': 4.26, 'petal_width': 1.3259999999999998}, {'especie': 'Iris-virginica', 'sepal_length': 6.587999999999998, 'sepal_width': 2.9739999999999998, 'petal_length': 5.552, 'petal_width': 2.026}]

# %%
#5. Comparación Interactiva de Características entre Especies


def comparar_caracteristica():
  print("Opciones de características: ",columnas_numericas)
  opcion = input("\n¿Qué característica deseas comparar? (Ingresa el nombre): ").strip().lower()

  if opcion == "sepal_length":
    caracteristica = "sepal_length"
  elif opcion == "sepal_width":
    caracteristica = "sepal_width"
  elif opcion == "petal_length":
    caracteristica = "petal_length"
  elif opcion == "petal_width":
    caracteristica = "petal_width"
  else:
    print("Opción no válida")

  valor_maximo = 0

  for especie in df_iris['species'].unique():
    datos_especie = df_iris[df_iris['species'] == especie]
    promedio = calcular_promedio(datos_especie[caracteristica])
    if promedio > valor_maximo:
              valor_maximo = promedio
              especie_max = especie

  return especie_max, caracteristica, valor_maximo

print(comparar_caracteristica())
# Out:
# Opciones de características:  ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
#
# ¿Qué característica deseas comparar? (Ingresa el nombre): sepal_length
# ('Iris-virginica', 'sepal_length', 6.587999999999998)

# %%
#6. Búsqueda y Conteo de un Dato Específico
# 6. Búsqueda y Conteo de un Dato Específico

def buscar_y_contar(df):
    columnas = df.columns.tolist()
    print("Opciones de columnas: ",columnas)

    columna = input("\n¿En qué columna querés buscar? (Ingresá el nombre exacto): ").strip()
    print("Columna a buscar",columna)

    if columna in df.columns:
      valor_buscar = input(f"¿Qué valor querés buscar en la columna '{columna}'? ")
      print("valor a buscar",valor_buscar)
      valor_buscar = float(valor_buscar)
      contador = 0
      for valor in df[columna]:
        if valor == valor_buscar:
          contador += 1
    else:
      print(f"La columna '{columna}' no existe.")

    return contador

# Ejecutar la función
buscar_y_contar(df_iris)
# Out:
# Opciones de columnas:  ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
#
# ¿En qué columna querés buscar? (Ingresá el nombre exacto): sepal_length
# Columna a buscar sepal_length
# Tipo de dato de la columna 'sepal_length': float64
# Elemplo de dato =  5.1
# ¿Qué valor querés buscar en la columna 'sepal_length'? 5.1
# valor a buscar 5.1
# 9

# %%
#7. Cálculo de Suma Total

def calcular_suma_total(df):
    print("Columnas numéricas disponibles:", columnas_numericas)

    columna = input("\n¿Qué columna numérica querés sumar? (Ingresá el nombre exacto): ")
    print("Columna seleccionada:", columna)

    if columna in df.columns:
        suma_total = 0
        for valor in df[columna]:
            suma_total += valor
    else:
        print(f"La columna no existe.")
        suma_total = 0

    return suma_total

# Ejecutar la función
calcular_suma_total(df_iris)
# Out:
# Columnas numéricas disponibles: ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
#
# ¿Qué columna numérica querés sumar? (Ingresá el nombre exacto): sepal_width
# Columna seleccionada: sepal_width
# 458.10000000000014
